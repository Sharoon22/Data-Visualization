# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Company: The brand or manufacturer of the laptop (e.g., HP, Acer, Asus).
# Product: The model name or identifier of the laptop.
# TypeName: The type of laptop (e.g., Notebook, Ultrabook).
# Inches: The screen size of the laptop in inches.
# ScreenResolution: The resolution of the laptop screen (e.g., Full HD 1920x1080).
# Ram: The amount of RAM (memory) in the laptop, typically measured in GB (e.g., 8GB, 16GB).
# OpSys: The operating system installed on the laptop (e.g., Windows 10, No OS).
# Cpu Brand: The brand of the CPU (processor) used in the laptop (e.g., Intel, AMD).
# Cpu Model: The specific model of the CPU (e.g., Core i5 7200U, A9-Series 9420).
# Cpu Rate: The clock speed of the CPU, usually measured in GHz (e.g., 2.5GHz, 3GHz).
# SSD: The size of the Solid-State Drive (SSD) storage in GB (e.g., 256, 512).
# HDD: The size of the Hard Disk Drive (HDD) storage in GB (e.g., 500, 0).
# Flash Storage: The amount of additional flash storage in GB (often 0 if not present).
# Hybrid: Indicates whether the laptop has a hybrid storage setup.
# Gpu Brand: The brand of the Graphics Processing Unit (GPU) (e.g., Intel, Nvidia, AMD).
# Gpu Model: The specific model of the GPU (e.g., HD Graphics 620, Radeon R5).
# Price_euros: The price of the laptop in euros (€).

# %%
lap=pd.read_csv('/Users/sharoonkk/Desktop/DA/Matplotib/Laptop-Price.csv')

# %%
lap
# Out:
#      Company                                    Product            TypeName  \
# 0         HP                                     250 G6            Notebook
# 1       Acer                                   Aspire 3            Notebook
# 2       Asus                            ZenBook UX430UN           Ultrabook
# 3       Acer                                    Swift 3           Ultrabook
# 4         HP                                     250 G6            Notebook
# ...      ...                                        ...                 ...
# 1141    Dell                              Inspiron 3567            Notebook
# 1142    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1143  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1144  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1145      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
#
# ...

# %%
lap.duplicated().sum()
# Out:
# 18

# %%
lap.drop_duplicates(inplace=True)

# %%
lap.duplicated().sum()
# Out:
# 0

# %%
lap.isnull().sum()
# Out:
# Company                0
# Product                0
# TypeName               0
# Inches                 0
# ScreenResolution       0
# Ram                    0
# OpSys                  0
# Cpu Brand              0
# Cpu Model              0
# Cpu Rate               0
# SSD                    0
# HDD                    0
# Flash Storage          0
# Hybrid                 0
# Gpu Brand              0
# Gpu Model              0
# Unnamed: 16         1128
# Price_euros            0
# dtype: int64

# %%
lap
# Out:
#      Company                                    Product            TypeName  \
# 0         HP                                     250 G6            Notebook
# 1       Acer                                   Aspire 3            Notebook
# 2       Asus                            ZenBook UX430UN           Ultrabook
# 3       Acer                                    Swift 3           Ultrabook
# 4         HP                                     250 G6            Notebook
# ...      ...                                        ...                 ...
# 1123    Dell                              Inspiron 3567            Notebook
# 1124    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1125  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1126  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1127      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
#
# ...

# %%
lap.drop(columns='Unnamed: 16',inplace=True)

# %%
lap
# Out:
#      Company                                    Product            TypeName  \
# 0         HP                                     250 G6            Notebook
# 1       Acer                                   Aspire 3            Notebook
# 2       Asus                            ZenBook UX430UN           Ultrabook
# 3       Acer                                    Swift 3           Ultrabook
# 4         HP                                     250 G6            Notebook
# ...      ...                                        ...                 ...
# 1123    Dell                              Inspiron 3567            Notebook
# 1124    Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce            Notebook
# 1125  Lenovo                             Yoga 500-14ISK  2 in 1 Convertible
# 1126  Lenovo                             Yoga 900-13ISK  2 in 1 Convertible
# 1127      HP        15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
#
# ...

# %%
lap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1128 entries, 0 to 1127
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1128 non-null   object
#  1   Product           1128 non-null   object
#  2   TypeName          1128 non-null   object
#  3   Inches            1128 non-null   float64
#  4   ScreenResolution  1128 non-null   object
#  5   Ram               1128 non-null   object
#  6   OpSys             1128 non-null   object
#  7   Cpu Brand         1128 non-null   object
#  8   Cpu Model         1128 non-null   object
#  9   Cpu Rate          1128 non-null   object
#  10  SSD               1128 non-null   int64
#  11  HDD               1128 non-null   int64
#  12  Flash Storage     1128 non-null   int64
#  13  Hybrid            1128 non-null   int64
#  14  Gpu Brand         1128 non-null   object
#  15  Gpu Model         1128 non-null   object
# ...

# %%
lap.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'ScreenResolution', 'Ram',
#        'OpSys', 'Cpu Brand', 'Cpu Model', 'Cpu Rate', 'SSD', 'HDD',
#        'Flash Storage', 'Hybrid', 'Gpu Brand', 'Gpu Model', 'Price_euros'],
#       dtype='object')

# %%
lap.shape
# Out:
# (1128, 17)

# %%
lap.nunique(
    
)
# Out:
# Company              17
# Product             527
# TypeName              6
# Inches               15
# ScreenResolution     34
# Ram                   8
# OpSys                 7
# Cpu Brand             2
# Cpu Model            65
# Cpu Rate             27
# SSD                   9
# HDD                   7
# Flash Storage         4
# Hybrid                3
# Gpu Brand             3
# Gpu Model            96
# Price_euros         706
# dtype: int64

# %% [markdown]
# ## Line plot for identifying company and cpu model according to the type

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='Company',y='Cpu Model',data=lap,hue='TypeName',marker='o')
plt.xticks(rotation=90)
plt.title('laptop Sales')
plt.show()

# %% [markdown]
# ## Barplot for identifying the price of laptop according to their type

# %%
plt.figure(figsize=(15,10))
sns.barplot(x='TypeName',y='Price_euros',data=lap)
plt.xticks(rotation=90)
plt.title('laptop Sales')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.barplot(y='SSD',x='Company',data=lap,hue='TypeName')
plt.xticks(rotation=90)
plt.title('laptop Sales')
plt.show()

# %% [markdown]
# ## Heatmap

# %%
lapt=lap.select_dtypes(include='number').corr()

# %%
sns.heatmap(lapt.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x='Company',y='Cpu Rate',data=lap,hue='TypeName',marker='o')
plt.xticks(rotation=90)
plt.title('cpu performace')
plt.show()

# %%
sns.boxplot(lap)
# Out:
# <Axes: >

# %% [markdown]
# ## The total price of Laptop according to their Companies

# %%
price=lap.groupby('Company')['Price_euros'].sum()

# %%
pric=pd.DataFrame(price)

# %%
sns.barplot(x='Company',y='Price_euros',data=pric)
plt.xticks(rotation=90)
plt.title('Total price')
plt.show()

# %% [markdown]
# ## viloin plot

# %%
sns.violinplot(x='TypeName',y='Price_euros',data=lap)
plt.xticks(rotation=90)
plt.title('laptop Sales')
plt.show()

# %% [markdown]
# ## Scatter plot according to their company and price

# %%
sns.scatterplot(x='Company',y='Price_euros',data=lap)
plt.xticks(rotation=90)
plt.title('laptop Sales')
plt.show()

# %%
plt.figure(figsize=(10,15))
sns.jointplot(x='Company',y='Price_euros',data=lap,kind='hist')
plt.title('laptop Sales')
plt.show()

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(lap)

# %%
pr=lap.groupby('TypeName')['Price_euros'].sum().plot(kind='pie',explode=(0,0,0.3,0,0,0),shadow=True,autopct="%1.f%%",startangle=90);
