# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
games=pd.read_csv('/Users/sharoonkk/Desktop/DA/Matplotib/Online_game.csv')

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### Description
#
# * This dataset appears to represent video game sales data, containing information about 16,598 video games.
# * Each row corresponds to a specific video game, and the dataset includes the following columns
#    * Rank: A unique integer identifier that ranks the video games based on a specific criterion (likely sales    * Name: The name of the video ga
#     * Platform: The gaming platform on which the video game was released (e.g., PS4, Xbox One,
#     * Year: The ye game was released. This column has some missing values, with 16,327 non-null entries out of 16,598.
#     * Genre: The genre of the video game (e.g., Action, Sports, RPG).
#     * Publisher: The company that published the video game. There are a few missing values, with 16,540 non-null entries.
#     * NA_Sales: Sales in North America, measured in millions of units.
#     * EU_Sales: Sales in Europe, measured in millions of units.
#     * JP_Sales: Sales in Japan, measured in millions of units.
#     *
# Other_Sales: Sales in regions other than North America, Europe, and Japan, measured in millions of units.
#     * Global_Sales: The total global sales of the video game, measured in millions of units.ar the

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
games.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
games.fillna(0,inplace=True)

# %%
games.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
games.duplicated().sum()
# Out:
# 0

# %%
games.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   1973.647307      0.264667      0.146652      0.077782
# std     4791.853933    254.346809      0.816683      0.505351      0.309291
# min        1.000000      0.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
games.describe().T
# Out:
#                 count         mean          std      min      25%      50%  \
# Rank          16598.0  8300.605254  4791.853933     1.00  4151.25  8300.50
# Year          16327.0  2006.406443     5.828981  1980.00  2003.00  2007.00
# NA_Sales      16598.0     0.264667     0.816683     0.00     0.00     0.08
# EU_Sales      16598.0     0.146652     0.505351     0.00     0.00     0.02
# JP_Sales      16598.0     0.077782     0.309291     0.00     0.00     0.00
# Other_Sales   16598.0     0.048063     0.188588     0.00     0.00     0.01
# Global_Sales  16598.0     0.537441     1.555028     0.01     0.06     0.17
#
#                    75%       max
# Rank          12449.75  16600.00
# Year           2010.00   2020.00
# NA_Sales          0.24     41.49
# EU_Sales          0.11     29.02
# JP_Sales          0.04     10.22
# Other_Sales       0.04     10.57
# Global_Sales      0.47     82.74

# %%
games
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
games['Publisher'].unique()
# Out:
# array(['Nintendo', 'Microsoft Game Studios', 'Take-Two Interactive',
#        'Sony Computer Entertainment', 'Activision', 'Ubisoft',
#        'Bethesda Softworks', 'Electronic Arts', 'Sega', 'SquareSoft',
#        'Atari', '505 Games', 'Capcom', 'GT Interactive',
#        'Konami Digital Entertainment',
#        'Sony Computer Entertainment Europe', 'Square Enix', 'LucasArts',
#        'Virgin Interactive', 'Warner Bros. Interactive Entertainment',
#        'Universal Interactive', 'Eidos Interactive', 'RedOctane',
#        'Vivendi Games', 'Enix Corporation', 'Namco Bandai Games',
#        'Palcom', 'Hasbro Interactive', 'THQ', 'Fox Interactive',
#        'Acclaim Entertainment', 'MTV Games', 'Disney Interactive Studios',
#        nan, 'Majesco Entertainment', 'Codemasters', 'Red Orb', 'Level 5',
#        'Arena Entertainment', 'Midway Games', 'JVC', 'Deep Silver',
#        '989 Studios', 'NCSoft', 'UEP Systems', 'Parker Bros.', 'Maxis',
# ...

# %% [markdown]
# ## 1 Retrieve the geners by Activision

# %%
act=games[games['Publisher']=='Activision'][['Genre','Publisher']]
act
# Out:
#          Genre   Publisher
# 29     Shooter  Activision
# 31     Shooter  Activision
# 33     Shooter  Activision
# 34     Shooter  Activision
# 35     Shooter  Activision
# ...        ...         ...
# 16411   Action  Activision
# 16444   Action  Activision
# 16501  Shooter  Activision
# 16537   Action  Activision
# 16595   Racing  Activision
#
# [975 rows x 2 columns]

# %%
act.nunique()
# Out:
# Genre        12
# Publisher     1
# dtype: int64

# %% [markdown]
# ## 2 retrieve the total no of sales by Nintendo in Europe

# %%
g=games['EU_Sales'][games['Publisher']=='Nintendo'].max()

# %%
g
# Out:
# 29.02

# %% [markdown]
# ## 3 Retrieve the game that has highest sale in 2008

# %%
max=games.groupby(['Year'])

# %%
max=ma.get_group(2010)
max
# Out:
# /var/folders/n8/js2blnd547x1vm4qzc05tq5c0000gn/T/ipykernel_2295/3818359229.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   max=max.get_group(2010)
#         Rank                                               Name Platform  \
# 15        16                                 Kinect Adventures!     X360
# 26        27                        Pokemon Black/Pokemon White       DS
# 31        32                            Call of Duty: Black Ops     X360
# 40        41                            Call of Duty: Black Ops      PS3
# 54        55                                     Gran Turismo 5      PS3
# ...      ...                                                ...      ...
# 16437  16440              The Cages: Pro Style Batting Practice      Wii
# 16478  16481                 Ishin no Arashi: Shippuu Ryuumeden       DS
# ...

# %% [markdown]
# ## 4 Publisher with highest sale in EUROPE

# %%
games.groupby(['Publisher'])['EU_Sales'].max().idxmax()
# Out:
# 'Nintendo'

# %% [markdown]
# ## 5 List out the sports by Konami Digital Entertainment

# %%
sp=games.groupby(['Genre'])

# %%
sp=sp.get_group('Sports')
sp
# Out:
# /var/folders/n8/js2blnd547x1vm4qzc05tq5c0000gn/T/ipykernel_2295/2840322743.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   sp=sp.get_group('Sports')
#         Rank                           Name Platform    Year   Genre  \
# 0          1                     Wii Sports      Wii  2006.0  Sports
# 3          4              Wii Sports Resort      Wii  2009.0  Sports
# 13        14                        Wii Fit      Wii  2007.0  Sports
# 14        15                   Wii Fit Plus      Wii  2009.0  Sports
# 77        78                        FIFA 16      PS4  2015.0  Sports
# ...      ...                            ...      ...     ...     ...
# 16576  16579              Rugby Challenge 3     XOne  2016.0  Sports
# 16578  16581  Outdoors Unleashed: Africa 3D      3DS  2011.0  Sports
# ...

# %%
sp[sp['Publisher']=='Konami Digital Entertainment']
# Out:
#         Rank                                               Name Platform  \
# 249      250          Winning Eleven: Pro Evolution Soccer 2007      PS2
# 292      293                      World Soccer Winning Eleven 9      PS2
# 315      316        World Soccer Winning Eleven 8 International      PS2
# 348      349                          Pro Evolution Soccer 2008      PS2
# 474      475        World Soccer Winning Eleven 6 International      PS2
# ...      ...                                                ...      ...
# 16418  16421  Tennis no Oji-Sama: Doubles no Oji-Sama - Boys...       DS
# 16420  16423          Winning Eleven: Pro Evolution Soccer 2007       PC
# 16426  16429                               ESPN NBA 2Night 2002       XB
# 16437  16440              The Cages: Pro Style Batting Practice      Wii
# 16558  16561                          Pro Evolution Soccer 2008       PC
#
#          Year   Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %% [markdown]
# ##  6 The game that has played on ps2

# %%
ps2=games.groupby(['Platform'])

# %%
c=ps2.get_group('PS2')
# Out:
# /var/folders/n8/js2blnd547x1vm4qzc05tq5c0000gn/T/ipykernel_2295/2919429639.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   c=ps2.get_group('PS2')

# %%
c
# Out:
#         Rank                                              Name Platform  \
# 17        18                     Grand Theft Auto: San Andreas      PS2
# 24        25                       Grand Theft Auto: Vice City      PS2
# 28        29                            Gran Turismo 3: A-Spec      PS2
# 38        39                              Grand Theft Auto III      PS2
# 47        48                                    Gran Turismo 4      PS2
# ...      ...                                               ...      ...
# 16559  16562      Sugar + Spice! Anoko no Suteki na Nanimokamo      PS2
# 16561  16564                                    Kanokon: Esuii      PS2
# 16572  16575                  Scarlett: Nichijou no Kyoukaisen      PS2
# 16580  16583                                         Real Rode      PS2
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
#
#          Year      Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %% [markdown]
# ##  7 list out the adventure games

# %%
adv=games.groupby('Genre')

# %%
adv

# %%
c=adv.get_group('Adventure')

# %%
c
# Out:
#         Rank                                Name Platform    Year      Genre  \
# 50        51  Super Mario Land 2: 6 Golden Coins       GB  1992.0  Adventure
# 158      159                    Assassin's Creed     X360  2007.0  Adventure
# 218      219                    Assassin's Creed      PS3  2007.0  Adventure
# 251      252     Zelda II: The Adventure of Link      NES  1987.0  Adventure
# 400      401          Rugrats: Search For Reptar       PS  1998.0  Adventure
# ...      ...                                 ...      ...     ...        ...
# 16572  16575    Scarlett: Nichijou no Kyoukaisen      PS2  2008.0  Adventure
# 16575  16578               Neo Angelique Special      PSP  2008.0  Adventure
# 16580  16583                           Real Rode      PS2  2008.0  Adventure
# 16586  16589      Secret Files 2: Puritas Cordis       DS  2009.0  Adventure
# 16591  16594                 Myst IV: Revelation       PC  2004.0  Adventure
#
# ...

# %% [markdown]
# ##  8 retrive the game with highest Sales in Europe

# %%
gd=games['EU_Sales'].max()

# %%
gd
# Out:
# 29.02

# %% [markdown]
# ##  9 List out the top 10 highest sales in japan on 2004

# %%
hi=games.groupby(['Year'])

# %%
hig=hi.get_group(2004)
hig
# Out:
# /var/folders/n8/js2blnd547x1vm4qzc05tq5c0000gn/T/ipykernel_2295/1404695354.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   hig=hi.get_group(2004)
#         Rank                               Name Platform    Year  \
# 17        18      Grand Theft Auto: San Andreas      PS2  2004.0
# 47        48                     Gran Turismo 4      PS2  2004.0
# 58        59  Pokemon FireRed/Pokemon LeafGreen      GBA  2004.0
# 59        60                     Super Mario 64       DS  2004.0
# 79        80                             Halo 2       XB  2004.0
# ...      ...                                ...      ...     ...
# 16330  16333      Ultraman Fighting Evolution 3      PS2  2004.0
# 16362  16365                         Powerdrome       XB  2004.0
# 16375  16378               Colin McRae Rally 04       PC  2004.0
# ...

# %%
hig.nlargest(10,"JP_Sales")
# Out:
#       Rank                                           Name Platform    Year  \
# 180    181  Dragon Quest VIII: Journey of the Cursed King      PS2  2004.0
# 58      59              Pokemon FireRed/Pokemon LeafGreen      GBA  2004.0
# 130    131                        Pokémon Emerald Version      GBA  2004.0
# 1110  1112             Dragon Quest V: Tenkuu no Hanayome      PS2  2004.0
# 1351  1353          Classic NES Series: Super Mario Bros.      GBA  2004.0
# 59      60                                 Super Mario 64       DS  2004.0
# 686    688                             WarioWare Touched!       DS  2004.0
# 315    316    World Soccer Winning Eleven 8 International      PS2  2004.0
# 47      48                                 Gran Turismo 4      PS2  2004.0
# 1445  1447                               Samurai Warriors      PS2  2004.0
#
#              Genre                     Publisher  NA_Sales  EU_Sales  \
# 180   Role-Playing                   Square Enix      0.65      0.75
# ...

# %% [markdown]
# ##  10  List out the lowest sales in all countries on 2004

# %%
hig.nsmallest(1,["JP_Sales",'NA_Sales','Other_Sales','EU_Sales','Global_Sales'])
# Out:
#         Rank                   Name Platform    Year   Genre Publisher  \
# 16118  16121  Football Manager 2005       PC  2004.0  Sports      Sega
#
#        NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 16118       0.0      0.01       0.0          0.0          0.01

# %% [markdown]
# ## 11 In which all platforms Grand Theft Auto: San Andreas	was played

# %%
act=games[games['Name']=='Grand Theft Auto: San Andreas'][['Name','Platform']]
act
# Out:
#                                Name Platform
# 17    Grand Theft Auto: San Andreas      PS2
# 873   Grand Theft Auto: San Andreas       XB
# 2120  Grand Theft Auto: San Andreas       PC
# 9827  Grand Theft Auto: San Andreas     X360
